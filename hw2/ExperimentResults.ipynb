# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from plot import plot_data, get_datasets

# %% [markdown]
# ## Problem 4. CartPole

# %% [markdown]
# ### Compare the learning curves (average return at each iteration)for the experiments prefixed withsb_.  (The small batch experiments.

# %%
data = []
for log_dir in ['data/sb_no_rtg_dna_CartPole-v0_27-10-2018_14-07-55/', 
                'data/sb_rtg_dna_CartPole-v0_27-10-2018_14-09-29/',
                'data/sb_rtg_na_CartPole-v0_27-10-2018_14-10-43/']:
    data += get_datasets(log_dir)

# %%
plot_data(data)

# %% [markdown]
# ### Compare  the  learning  curves  for  the  experiments  prefixedwithlb_.  (The large batch experiments.)

# %%
data = []
for log_dir in ['data/lb_no_rtg_dna_CartPole-v0_27-10-2018_14-12-47/',
                'data/lb_rtg_dna_CartPole-v0_27-10-2018_14-17-30/',
                'data/lb_rtg_na_CartPole-v0_27-10-2018_14-22-10/']:
    data += get_datasets(log_dir)

# %%
plot_data(data)
